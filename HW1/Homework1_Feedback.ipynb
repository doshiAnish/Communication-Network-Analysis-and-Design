# %% [markdown]
# # Homework #1
# **Due:** Thursday January 11th, 11:59PM via Blackboard

# %% [markdown]
# **Name:** **ANISH DOSHI**,  **Student Id:** **ap2326**

# %% [markdown]
# ## Problem 1.  Layer Analysis of WAMP (40 pts)
# There is a new protocol being proposed for "application messaging" called the [Web Application Messaging Protocol (WAMP)](http://wamp-proto.org/). This has been submitted to the IETF for consideration in the form of an [Internet Draft](http://wamp-proto.org/static/rfc/draft-oberstet-hybi-crossbar-wamp.html). Note that this has no official status at the IETF yet.  You are going to analyze WAMP running over [Websockets](https://tools.ietf.org/html/rfc6455), running over TCP/IP. This will be a *layer* analysis which will explain what each layer in the stack is doing for us. We are concerned with *essential communications functionality*. This is not a security class so we will not be examining or considering the security features or additional security layers such as TLS. For example Websockets provides *masking* to prevent certain types of attacks but you do not need to mention this or other security features in your analysis.
#
# The goal here is a layer diagram and a "half page" of explanatory text suitable for use explaining to undergraduate taking a networking class how WAMP works with its supporting layers.
#
# 1. Draw a layer diagram (protocol *stack*) of WAMP over Websockets over TCP over IP
# 2. What essential functionality does IP provide in this *stack*? Hint we went over this on the first day of class and the answer should be just a sentence or two long.
# 3. What essential functionality does TCP provide in this *stack*?
# 4. Does TCP provide "message framing"? Or is it just a byte stream?
# 5. What essential functionalities does Websockets provide? Do not include resolving issues of "long-polling" or "multiple HTTP" connections since many of these issues are resolved in HTTP 2.0.  First does Websockets provide any key functionality over HTTP if so what? How? You might want to skip reading of most of [RFC6455](https://tools.ietf.org/html/rfc6455) and look at [section 5](https://tools.ietf.org/html/rfc6455#section-5) and think about the following questions: (a) does Websockets provide framing? (b) does it provide for binary or text based data transfer, (c) does it provide for control mechanisms?
# 6. Is Websockets (and HTTP) considered an application protocol? If so how can WAMP run on top of it? Aren't we at the "top"?
# 7. The WAMP protocol talks of a "WAMP Router"? Are they talking about layer 3 *routing* or somekind of switching at a higher layer? If a higher layer which? What is is switching? Hint see [section 6.](http://wamp-proto.org/static/rfc/draft-oberstet-hybi-crossbar-wamp.html#messages).
# 8. What additional functionality does WAMP provide over that of Websockets? Limit your description to 2-4 sentences.

# %% [markdown]
# A1. Following is the layer diagram:  *LAG* and *VCAT* have nothing to do with this. -2

# %% [markdown]
# ![layerDiagram1.png](attachment:layerDiagram1.png)

# %% [markdown]
# A2. IP provides the functionality of routing the packet. It is IP who makes it possible to route the pacake from source to destination.

# %% [markdown]
# A3.TCP defines the establishment and maintains the commun ication network via which applications exchange data.  **No**, TCP provides reliable communications. -5

# %% [markdown]
# A4.TCP operates on streams of data, never packets. There is no way to send a packet of data over TCP. However,most application protocols are based on the idea of messages. Thus, while design one must consider 'message framing' protocol.

# %% [markdown]
# A5.Websocket is a computer communication protocol, providing full duplex communication channels over single TCP connection. It is different TCP protocol from HTTP.It is designed on the principle, that there should be minimal framing. The only framing that exists is to make the protocol frame-based instead of stream-based. It provides both unicode text data and binary data transfer.The goal of this protocol is provide mechansim for browser-based applications that need two-way communication with servers.

# %% [markdown]
# A6.No, websocket is not considered as an application protocol. It is just a layer on top of TCP.

# %% [markdown]
# A7.WAMP runs on top of websocket, which is on top of transport layer. Thus, it is a routing which takes place at a higher layer, i.e. **No** *not* transport layer, *application laver*. -3

# %% [markdown]
# A8. Along with functionalities of the websocket, WAMP also provides with high level messaging patterns RPC+PubSub. It uses JSON as its messaging format. It allows us to decouple the application. It is language agnostic. -2

# %% [markdown]
# ## Problem 2. Multiple levels of human or packaging multiplexing (10pts)
# In packet switching we are used to multiple levels of multiplexing, e.g., packets within packets within packets. Does this ever occur in the case of human transport or package transport?  If so cite at least on example each (provide a link if available).

# %% [markdown]
# Yes, it does occur in case of human transport. The best examples for human package transport are bus, train, aeroplane.
#
# **Multiple levels of multiplexing, not single level -10**

# %% [markdown]
# ## Problem 3. Scientific Python Installation (10pts)
# Install a scientific python distribution such as [Anaconda](https://www.anaconda.com/what-is-anaconda/). Run the following commands at the console or in a Jupyter notebook:
#
# ```
# import sys
# print(sys.version)
# import networkx
# print(networkx.__version__)
# import numpy as np
# print(np.__version__)
# ```
#
# We are doing this check to see what versions of Python and critical libraries we have installed. Perform a screen capture of the results and include that in this notebook. Mine looks like ![python results](PythonInfoGB.png)

# %%
import sys
print(sys.version)
import networkx
print(networkx.__version__)
import numpy as np
print(np.__version__)
# Out:
# 3.6.3 |Anaconda, Inc.| (default, Oct 15 2017, 03:27:45) [MSC v.1900 64 bit (AMD64)]
# 2.0
# 1.13.3

# %% [markdown]
# ## Problem 4. HTTP Packet Trace Analysis via WireShark (20 pts)
# Install Wireshark and perform packet capture (you'll need to start the capture,when use visit an HTTP site (**not** HTTPS) for example http://www.grotto-networking.com.  I open a tab in my browser, start packet capture, enter the URL in the browser tab and get the page, then turn off packet capture.  In the top of WireShark window enter *http* as a filter. As shown below:
# ![Packet Capture](WireSharkCap.png)
#
# Take a screen shot of your packet capture and include it here. Answer the following questions:
# (a) What is your computers Ethernet address?
# (b) What is your computers IP address?
# (c) What is the servers IP address?
# (d) What are the TCP source and destination port numbers?
# (e) What verion of HTTP is being used?

# %% [markdown]
# Following is the wireshark packet capture:
# **Missing answers to parts (a)-(e) -8pts**

# %% [markdown]
# ![Wireshark packet capture](wireshark.png)

# %% [markdown]
# ## Problem 5. Installation of VirtualBox and Mininet VM (20 pts)
# Install VirtualBox and the Mininet VM. There are instructions on the Web. I first install (or upgrade) VirtualBox. I then get the Mininet VM zipped file and unzip it. In VirtualBox I then use the *File/Import Appliance...* menu item and point VirtualBox to the unzipped Mininet files.
#
# 1. What version of VirtualBox are you using?
# 2. Start up the Mininet VM and login. User name is: mininet, password is: mininet
# 3. Type `mn --version` into the Mininet VM window to get the mininet version.
# 4. Run `sudo mn --test pingall` to test Mininet. Capture the screen. I get something like
#
# ![Mininet VM Capture](MininetVM.png)

# %% [markdown]
# Following is the mininet screenshot: **what version of mininet -2**

# %% [markdown]
# ![mininet.png](attachment:mininet.png)
