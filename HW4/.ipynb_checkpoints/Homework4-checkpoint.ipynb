# %% [markdown]
# # Homework #4 (50 pts)
# **Due:** Tuesday January 30th, 10:00AM via Blackboard  **Note Date and Time** This is a short assignment to give you practice with optical technology.

# %% [markdown]
# **Name:** **Anish Doshi**,  **Student Id:** **ap2326**

# %% [markdown]
# *Note:* Use the "official" value of the speed of light $c = 2.99792458 × 10^8 m/s$ in any computation where it is needed.

# %% [markdown]
# ## Problem 1.  Optical Fiber (10 pts)
#
# **(a)** What is the bandwidth in THz (Tera Hertz) of the optical "O-band" (original band) that runs from 1260nm to 1360nm.
#
# **(b)** To go the longest distance what type of optical fiber would you need to use? (single mode or multi-mode)
#
# **(c)** If you needed to run 1Gbps Ethernet between two buildings less than two hundred meters apart what is the most cost effective type of fiber you could use? (single mode or multi-mode)
#
# **(d)** How does the attenuation of single mode optical fiber for 10Gbps signals compare to that of coaxial cable? (in rough orders of magnitude)
#
# **(e)** Which type of fiber (single mode or multi-mode) is harder to work with? Why?

# %% [markdown]
# A.1a. Using the fundamental relation, f = c/λ where f = frequency, c = speed of light and λ = wavelength  we calculate bandwidth of optical 'O-band' in following manner: for short end of the band, f = (2.9979 x 10^8)/1260 x 10^-9 = 237.9285 THz; for long end of the band, f = (2.9979 x 10^8)/1360 x 10^-9 = 220.4338 THz; thus, toal bandwidth in the Original band (O-band) is approx. 17.4947 THz, that is huge!!

# %% [markdown]
# A.1b. Single mode optical fiber (smf) provides upto 50 times more distance than multi-mode fiber. Smf has a much smaller core than multimode. The small core and single light-wave virtually eliminate any distortion that could result from overlapping light pulses, providing the least signal attenuation and the highest transmission speeds of any fiber cable type.

# %% [markdown]
# A.1c. Multimode fiber gives you high bandwidth at high speeds over medium distances. Light waves are dispersed into numerous paths as they travel through the cable’s core typically 850 or 1300nm. Typical multimode fiber core diameters are 50, 62.5, and 100 micrometers. Multimode fiber is best fit considering cost and bandwidth upto distance of 3-5 miles.

# %% [markdown]
# A.1d. For the coaxial cables operating near 10Ghz the attenuation is approximately 0.25dB/foot. Whereas, for modern SMF fiber optic cables operating near 1550nm attenuation is approximately 0.2dB/km. The comparision is in per foot vs per km; that is arpprox. order of three magnitude improvement using smf.

# %% [markdown]
# A.1e. Single mode fiber(smf) is comparatively more harder to work with because it has a smaller core diamater of 8-10μm.

# %% [markdown]
# ## Problem 2. Single Channel Optical Systems (10pts)
#
# In this example we'll look at a 40GBASE-FR system. An optical [transceiver](https://www.smartoptics.com/wp-content/uploads/2015/08/SO-CFP-40GBase-FR4-Rev-4.2.pdf) (transmitter and receiver in a combined package) has a transmitter with a central wavelength of 1550nm, and an output power of +3dBm.  The receiver has a sensitivity of -6dBm. Note that 40GBASE-FR uses a single wavelength with a digital signal running at approximately
#
# **(a)** If the minimum quality fiber optic cable permitted has an attenuation of 0.5dB/km and no other impairments affected the system how far could this system reach?  (Show your work)
#
# **(b)** If the maximum distance specified for 40GBASE-FT is 2km how much *margin* (excess power) in terms of dB do we get in the system when it only runs 2km as opposed to what you calculated in part (a).
#
# **(c)** If we assume each cable connection or cable splice costs us 0.5dB of extra attenuation, how many connections or splices can we have in our system between transmitter and receiver?

# %% [markdown]
# A.2a. Refer following screenshot of calculations for this problem: ![2a.JPG](attachment:2a.JPG)

# %% [markdown]
# A.2b. With refrence to problem 2a, total distancce is 18km, of which only 2km is being run. Therfore, excess of 16km distance is the margin, i.e. excess power in terms of dB is 8dB as α is 0.5/km.

# %% [markdown]
# A.2c. Total attenution possible is 9dB as 0.5/km for 18km and loss per connection is 1.5dB then total number of connections possible = 9/1.5 = 6 connections.

# %% [markdown]
# ## Problem 3. Multi-Channel Optical Systems (10pts)
#
# I saw that a company online that sells an [Erbium Doped Fiber Amplifier](https://www.fs.com/products/36524.html) with 26dB of gain that operates over a wavelength range of 1528nm-1564nm.  You must show how you would make any calculations below.
#
# **(a)** If 100GBASE–LR4 and 100GBASE–ER4 (100Gbps Ethernet physical layers) use the four center frequencies of 229THz, 229.8THz, 230.6THz, and 231.4THz could you apply the above amplifier to extend the reach of these systems?
#
# **(b)** The manufacturer claims that this amplifier can be used in 40 channel WDM systems. If so what is the approximate channel spacing in GHz between the channels? I'm not concerned with off by one issues or "guard bands" here.  Are these channels a lot closer or farther apart than the 100GBASE-LR4 channel?
#
# **(c)** If I use this optical amplifier and assume 3dB of loss for connections to and from the amplifier how much farther can I send my signal assuming an system with a fiber cable with an attenuation of 0.30dB/km?

# %% [markdown]
# A.3a. In order to see if the amplifier can reach this systems we need to check if it can reach the frequencies of these systems. So, frequency f1 = c/w1 = (2.9979 x 10^8)/1528 x 10^-9 = 196.19 THz and frequency f2 = c/w2 = (2.9979 x 10^8)/1564 x 10^-9 = 191.68 THz. Since both the amplifer and the systems are having different frequencies, it can not be reached.

# %% [markdown]
# A.3b. Considering the values fom 3a, channel spacing is (196190-191680)/40 = 112.75 GHz. For the 100GBASE-LR4, channel spacing is 229800-229000 = 800GHz. These system channels are farther apart from 100GBASE-LR4.

# %% [markdown]
# A.3c. We know, αL = dB. Here α = 0.30dB/km and dB = (26-3-3) = 20 dB. Therefore, L = 20/0.3 = 66.67 km. Hence, you can send the signal upto 67km far away.

# %% [markdown]
# ## Problem 4. TDM Optical Signals (10pts)
#
# In the figure below we show the repeating frame structure of a G.709 OTUk (k=0,...,4) digital signal. Below that figure we show that we show the repetition periods for the various OTUk signals. Note that each *column* represents a byte.
# ![OTUk](OTUkFrame.png)
# ![OTUk Frame times](G709FrameRates.png)
#
# **(a)** What is the transmission rate for an OTU4 signal with and without the FEC given the period shown in the chart above?
#
# **(b)** With the period show for an OTU4 signal and the two bytes allocated to the *General Communications Channel 0* what is the raw bandwidth of this "extra" communications channel?
#
# **(c)** Calculate the bandwidth efficiency of an OTUk signal as a ratio of payload bytes to total bytes **not** counting the FEC bytes, **but** assuming the first 14 bytes of every row is used for overhead (not just the first row).
#
# **(d)** Calculate the bandwidth efficiency of a 1500 byte Ethernet packet as a ratio of payload bytes to total bytes. Is it better or worse than an OTUk?

# %% [markdown]
# A.4a. Transmission rate is data transfered per unit time. Generally data is measured in bits and time in seconds. For OTU4 signal, without FEC tansmission rate is (3824 x 4 x 8)/ 1.168 x 10^-6 = 104.76 Gbps and with FEC transmission rate is [(3824 x 4 x 8) + (256 x 4 x 8)]/ 1.168 x 10^-6 = 111.78 Gbps

# %% [markdown]
# A.4b. Considering the only extra GCC 2 byte, raw bandwidth =  (2 x 4 x 8)/ 1.168 x 10^-6 = 0.054794 Gbps

# %% [markdown]
# A.4c. Bandwidth efficiency for an OTUk signal is defined as ratio of payload bytes/total byte (exculding FEC byte). Thus, bandwidth efficency is (3810 x 4)/(3824 x 4) = **0.9963**

# %% [markdown]
# A.4d. Bandwidth efficiency for an Ethernet packet is 1500/1518 = **0.9881** The bandwidth for ethernet packet is not as good as for OTUk.

# %% [markdown]
# ## Problem 5. Optical Networks (10 pts)
# Types of optical networks and a bit on GMPLS
#
# **(a)** Rank in terms of power consumption the following types of switches with 1Tbps switching capacity (i) an IP router, (ii) an WDM wavelength switch, (iii) A TDM switch working with G.709 signals.
#
# **(b)** Which of the three types of switches mentioned above provide 3R regeneration functionality?

# %% [markdown]
# A.5a. In terms of power consumption, optical switching is the most efficient than comes the TDM switch and lastly the IP router.

# %% [markdown]
# A.5b. Currently only the WDM switches provide the 3R regenration functioanlity.
